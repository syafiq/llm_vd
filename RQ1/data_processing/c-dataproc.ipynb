# %%
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3 as lite
from sqlite3 import Error
from pathlib import Path
from datetime import date
import numpy as np
import matplotlib.ticker as tick
import requests
import difflib as diff
import re 
import csv
import ast
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
# %matplotlib inline

# pd.set_option('mode.chained_assignment', None)

def create_connection(db_file):
    """
    create a connection to sqlite3 database
    """
    conn = None
    try:
        conn = lite.connect(db_file, timeout=10)  # connection via sqlite3
    except Error as e:
        print(e)
    return conn

conn = create_connection("../CVEfixes.db")

query = """
    SELECT m.code, m.before_change, c.committer_date
    FROM file_change f, method_change m, commits c
    WHERE m.file_change_id = f.file_change_id
    AND c.hash = f.hash
    AND f.programming_language IN ('C', 'C++');
"""

df = pd.read_sql_query(query, conn)
df
# Out:
#                                                     code before_change  \
# 0      _dl_dst_count (const char *name, int is_path)\...         False
# 1      _dl_dst_count (const char *name, int is_path)\...          True
# 2      _dl_dst_substitute (struct link_map *l, const ...          True
# 3      _dl_dst_substitute (struct link_map *l, const ...         False
# 4      expand_dynamic_string_token (struct link_map *...          True
# ...                                                  ...           ...
# 20055  HeifInput::seek_subimage(int subimage, int mip...         False
# 20056  HeifInput::seek_subimage(int subimage, int mip...          True
# 20057  static bool gguf_ex_read_0(const std::string &...         False
# 20058  struct gguf_context * gguf_init_from_file(cons...         False
# 20059  struct gguf_context * gguf_init_from_file(cons...          True
#
#                   committer_date
# 0      1999-11-10 02:42:49+00:00
# 1      1999-11-10 02:42:49+00:00
# 2      1999-11-10 02:42:49+00:00
# 3      1999-11-10 02:42:49+00:00
# 4      1999-11-10 02:42:49+00:00
# ...                          ...
# 20055  2024-07-15 09:30:17-04:00
# 20056  2024-07-15 09:30:17-04:00
# 20057  2024-07-20 17:15:42+03:00
# 20058  2024-07-20 17:15:42+03:00
# 20059  2024-07-20 17:15:42+03:00
#
# [20060 rows x 3 columns]

# %%
df = df.drop_duplicates(subset=['code'], ignore_index=True)

# %%
df = df.rename(columns={'before_change': 'label', 'code': 'text'})
df
# Out:
#                                                     text  label  \
# 0      _dl_dst_count (const char *name, int is_path)\...  False
# 1      _dl_dst_count (const char *name, int is_path)\...   True
# 2      _dl_dst_substitute (struct link_map *l, const ...   True
# 3      _dl_dst_substitute (struct link_map *l, const ...  False
# 4      expand_dynamic_string_token (struct link_map *...   True
# ...                                                  ...    ...
# 19360  HeifInput::seek_subimage(int subimage, int mip...  False
# 19361  HeifInput::seek_subimage(int subimage, int mip...   True
# 19362  static bool gguf_ex_read_0(const std::string &...  False
# 19363  struct gguf_context * gguf_init_from_file(cons...  False
# 19364  struct gguf_context * gguf_init_from_file(cons...   True
#
#                   committer_date
# 0      1999-11-10 02:42:49+00:00
# 1      1999-11-10 02:42:49+00:00
# 2      1999-11-10 02:42:49+00:00
# 3      1999-11-10 02:42:49+00:00
# 4      1999-11-10 02:42:49+00:00
# ...                          ...
# 19360  2024-07-15 09:30:17-04:00
# 19361  2024-07-15 09:30:17-04:00
# 19362  2024-07-20 17:15:42+03:00
# 19363  2024-07-20 17:15:42+03:00
# 19364  2024-07-20 17:15:42+03:00
#
# [19365 rows x 3 columns]

# %%
df.loc[df.label == 'False', 'label'] = 0
df.loc[df.label == 'True', 'label'] = 1
df
# Out:
#                                                     text label  \
# 0      _dl_dst_count (const char *name, int is_path)\...     0
# 1      _dl_dst_count (const char *name, int is_path)\...     1
# 2      _dl_dst_substitute (struct link_map *l, const ...     1
# 3      _dl_dst_substitute (struct link_map *l, const ...     0
# 4      expand_dynamic_string_token (struct link_map *...     1
# ...                                                  ...   ...
# 19360  HeifInput::seek_subimage(int subimage, int mip...     0
# 19361  HeifInput::seek_subimage(int subimage, int mip...     1
# 19362  static bool gguf_ex_read_0(const std::string &...     0
# 19363  struct gguf_context * gguf_init_from_file(cons...     0
# 19364  struct gguf_context * gguf_init_from_file(cons...     1
#
#                   committer_date
# 0      1999-11-10 02:42:49+00:00
# 1      1999-11-10 02:42:49+00:00
# 2      1999-11-10 02:42:49+00:00
# 3      1999-11-10 02:42:49+00:00
# 4      1999-11-10 02:42:49+00:00
# ...                          ...
# 19360  2024-07-15 09:30:17-04:00
# 19361  2024-07-15 09:30:17-04:00
# 19362  2024-07-20 17:15:42+03:00
# 19363  2024-07-20 17:15:42+03:00
# 19364  2024-07-20 17:15:42+03:00
#
# [19365 rows x 3 columns]

# %%
print('Vulnerable:', len(df[df['label'] == 1]))
print('Not vulnerable:', len(df[df['label'] == 0]))
# Out:
# Vulnerable: 7810
# Not vulnerable: 11555

# %% [raw]
# # Randomly drop non vulnerable code until it reaches a 50/50 split
# df_balanced = df.drop(df[df['label'] == 0].sample(frac=.43834808).index)
# df_balanced = df_balanced.reset_index()
# df_balanced

# %% [raw]
# print('Vulnerable:', len(df_balanced[df_balanced['label'] == 1]))
# print('Not vulnerable:', len(df_balanced[df_balanced['label'] == 0]))

# %% [raw]
# df.to_json('java_unprocessed_date.json', orient='records')
# df_balanced.to_json('java_balanced_date.json', orient='records')

# %% [raw]
# df_balanced_nodate = df_balanced.drop(df_balanced.columns[[0,3]], axis=1)
# df_balanced_nodate

# %% [raw]
# from sklearn.model_selection import train_test_split
#
# train, test = train_test_split(df_balanced_nodate, test_size=0.2)
# train = train.reset_index(drop=True)
# test = test.reset_index(drop=True)

# %% [raw]
# train.to_json('java_train.json', orient='records')
# test.to_json('java_test.json', orient='records')

# %% [raw]
# !pwd

# %% [raw]
# df = pd.read_json('java_balanced_date.json')
# df

# %%
# Prevent time traveling
from sklearn.model_selection import train_test_split
#df['committer_date'] = pd.to_datetime(df['committer_date'])
df = df.sort_values(by='committer_date')
dfx = df.drop(df.columns[[2]], axis=1)
split_index = int(len(df) * 0.8)
train = dfx.iloc[:split_index]
test = dfx.iloc[split_index:]
test, validation = train_test_split(test, test_size=0.5)
train.to_json('c_date_train.json', orient='records')
validation.to_json('c_date_valid.json', orient='records')
test.to_json('c_date_test.json', orient='records')

# %% [raw]
# df['committer_date'] = pd.to_datetime(df['committer_date'])

# %% [raw]
# df = df.sort_values(by='committer_date')
# df

# %% [raw]
# split_index = int(len(df) * 0.8)
# train_df = df.iloc[:split_index]
# test_df = df.iloc[split_index:]

# %% [raw]
# print(len(train_df[train_df['label'] == 0]))
# print(len(train_df[train_df['label'] == 1]))
# print(len(test_df[test_df['label'] == 0]))
# print(len(test_df[test_df['label'] == 1]))

# %% [raw]
# train_df.to_json('java_notimetravelling_train.json', orient='records')
# test_df.to_json('java_notimetravelling_test.json', orient='records')
